# %%
import sys
import os
sys.path.append(os.path.abspath(os.path.join(os.pardir)))

from pyoscomp.scenario.components.performance import PerformanceComponent
from pyoscomp.scenario.components.supply import SupplyComponent

# Verify PerformanceComponent can be instantiated
supply = SupplyComponent('test/')
perf = PerformanceComponent('test/', supply)
assert perf.supply is supply
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 9
#       6 from pyoscomp.scenario.components.supply import SupplyComponent
#       8 # Verify PerformanceComponent can be instantiated
# ----> 9 supply = SupplyComponent('test/')
#      10 perf = PerformanceComponent('test/', supply)
#      11 assert perf.supply is supply
#
# File ~/Documents/pypsa-playground/pyoscomp/scenario/components/supply.py:40, in SupplyComponent.__init__(self, scenario_dir)
#      37 super().__init__(scenario_dir)
#      39 # Check prerequisites
# ---> 40 self.years, self.regions = self.check_prerequisites(time=True, topology=True)
#      41 self.time_axis = self.load_time_axis()
#      43 # Supply parameters
#
# File ~/Documents/pypsa-playground/pyoscomp/scenario/components/supply.py:65, in SupplyComponent.check_prerequisites(self, **kwargs)
#      60 """
#      61 Check that required components (Time, Topology) are initialized in the scenario.
#      62 Raises an error if any prerequisite is missing.
#      63 """
#      64 # Check Time Component
# ---> 65 years = self.read_csv("YEAR.csv", ["VALUE"])["VALUE"].tolist()
#      66 if not years:
#      67     raise AttributeError("Time component is not defined for this scenario.")
#
# File ~/Documents/pypsa-playground/pyoscomp/scenario/components/base.py:34, in ScenarioComponent.read_csv(self, filename, expected_columns)
#      32 path = os.path.join(self.scenario_dir, filename)
#      33 if not os.path.exists(path):
# ---> 34     raise FileNotFoundError(f"Required parameter file '{filename}' not found in scenario directory.")
#      35 df = pd.read_csv(path)
#      36 if len(expected_columns) > 0:
#
# FileNotFoundError: Required parameter file 'YEAR.csv' not found in scenario directory.
