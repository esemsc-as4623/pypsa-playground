# %%
import atlite
import logging

logging.basicConfig(level=logging.INFO)

# %%
cutout = atlite.Cutout(
    path="western-europe-2011-01.nc",
    module="era5",
    x=slice(-13.6913, 1.7712),
    y=slice(49.9096, 60.8479),
    time="2011-01",
)
# Out:
# INFO:atlite.cutout:Building new cutout western-europe-2011-01.nc

# %%
cutout.prepare()
# Out:
# INFO:atlite.data:Storing temporary files in /tmp/tmpksecki3r
# INFO:atlite.data:Calculating and writing with module era5:
# INFO:atlite.datasets.era5:Requesting data for feature temperature...
# INFO:atlite.datasets.era5:Requesting data for feature influx...
# INFO:atlite.datasets.era5:Requesting data for feature height...
# INFO:atlite.datasets.era5:Requesting data for feature runoff...
# INFO:atlite.datasets.era5:Requesting data for feature wind...
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	10m_u_component_of_wind (2011-[1])
# 	10m_v_component_of_wind (2011-[1])
# 	100m_u_component_of_wind (2011-[1])
# 	100m_v_component_of_wind (2011-[1])
# 	forecast_surface_roughness (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache-1/2025-11-18/4a9dc3bc28d732549c80d0ada427485e.grib
# 4a9dc3bc28d732549c80d0ada427485e.grib:   0%|          | 0.00/21.7M [00:00<?, ?B/s]
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	2m_temperature (2011-[1])
# 	soil_temperature_level_4 (2011-[1])
# 	2m_dewpoint_temperature (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache-1/2025-11-18/b48ff43c7ac805a7a458921d06ce597e.grib
# b48ff43c7ac805a7a458921d06ce597e.grib:   0%|          | 0.00/11.8M [00:00<?, ?B/s]
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	runoff (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache-1/2025-11-18/aa48d9779f037fbcd080a155aedb2b9f.grib
# aa48d9779f037fbcd080a155aedb2b9f.grib:   0%|          | 0.00/3.95M [00:00<?, ?B/s]
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	geopotential (2011-1)
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache-2/2025-11-18/bda30271cc3263919ae012c0b2b46247.grib
# bda30271cc3263919ae012c0b2b46247.grib:   0%|          | 0.00/8.10k [00:00<?, ?B/s]
# INFO:atlite.datasets.era5:CDS: Downloading variables
# 	surface_net_solar_radiation (2011-[1])
# 	surface_solar_radiation_downwards (2011-[1])
# 	toa_incident_solar_radiation (2011-[1])
# 	total_sky_direct_solar_radiation_at_surface (2011-[1])
#
# INFO:multiurl.base:Downloading https://object-store.os-api.cci2.ecmwf.int:443/cci2-prod-cache-1/2025-11-18/69f71ebf014e2fb5ca28cbf0bd998f1.grib
# 69f71ebf014e2fb5ca28cbf0bd998f1.grib:   0%|          | 0.00/15.8M [00:00<?, ?B/s]
# <Cutout "western-europe-2011-01">
#  x = -13.50 ⟷ 1.75, dx = 0.25
#  y = 50.00 ⟷ 60.75, dy = 0.25
#  time = 2011-01-01 ⟷ 2011-01-31, dt = h
#  module = era5
#  prepared_features = ['height', 'wind', 'influx', 'temperature', 'runoff']

# %%
cutout.data
# Out:
# <xarray.Dataset> Size: 138MB
# Dimensions:               (x: 62, y: 44, time: 744)
# Coordinates:
#   * x                     (x) float64 496B -13.5 -13.25 -13.0 ... 1.25 1.5 1.75
#   * y                     (y) float64 352B 50.0 50.25 50.5 ... 60.25 60.5 60.75
#   * time                  (time) datetime64[ns] 6kB 2011-01-01 ... 2011-01-31...
#     lon                   (x) float64 496B dask.array<chunksize=(62,), meta=np.ndarray>
#     lat                   (y) float64 352B dask.array<chunksize=(44,), meta=np.ndarray>
# Data variables: (12/15)
#     height                (y, x) float32 11kB dask.array<chunksize=(44, 62), meta=np.ndarray>
#     wnd100m               (time, y, x) float32 8MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     wnd_shear_exp         (time, y, x) float64 16MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     wnd_azimuth           (time, y, x) float32 8MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     roughness             (time, y, x) float32 8MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     influx_toa            (time, y, x) float32 8MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     ...                    ...
#     solar_altitude        (time, y, x) float64 16MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     solar_azimuth         (time, y, x) float64 16MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     temperature           (time, y, x) float32 8MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     soil temperature      (time, y, x) float32 8MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     dewpoint temperature  (time, y, x) float32 8MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
#     runoff                (time, y, x) float32 8MB dask.array<chunksize=(100, 44, 62), meta=np.ndarray>
# Attributes:
#     module:                  era5
#     prepared_features:       ['runoff', 'height', 'influx', 'temperature', 'w...
#     chunksize_time:          100
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2025-11-18T14:44 GRIB to CDM+CF via cfgrib-0.9.1...

# %%
cutout.prepared_features
# Out:
# module  feature
# era5    height                       height
#         wind                        wnd100m
#         wind                  wnd_shear_exp
#         wind                    wnd_azimuth
#         wind                      roughness
#         influx                   influx_toa
#         influx                influx_direct
#         influx               influx_diffuse
#         influx                       albedo
#         influx               solar_altitude
#         influx                solar_azimuth
#         temperature             temperature
#         temperature        soil temperature
#         temperature    dewpoint temperature
#         runoff                       runoff
# dtype: object

# %%
cutout.prepare(compression={"zlib": True, "complevel": 9})
# Out:
# INFO:atlite.data:Cutout already prepared.
# <Cutout "western-europe-2011-01">
#  x = -13.50 ⟷ 1.75, dx = 0.25
#  y = 50.00 ⟷ 60.75, dy = 0.25
#  time = 2011-01-01 ⟷ 2011-01-31, dt = h
#  module = era5
#  prepared_features = ['height', 'wind', 'influx', 'temperature', 'runoff']
